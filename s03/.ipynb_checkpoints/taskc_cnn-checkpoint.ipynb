# %%
import torch
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
import torch.nn as nn
class Flatten(nn.Module):
    def forward(self, x):
        x = x.view(x.size()[0], -1)
        return x

# %%
class PR_CNN(nn.Module):
    def __init__(self, **kwargs):
        super(PR_CNN, self).__init__()
        self.expected_input_size = kwargs.get('input_dim', None)

        # First layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=kwargs.get('input_channels', None),
                      out_channels=kwargs.get('input_channels', None)*5,
                      kernel_size=3,
                      stride=3),
            nn.LeakyReLU()
        )
        # Second layer
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=kwargs.get('input_channels', None)*5,
                      out_channels=kwargs.get('input_channels', None)*25,
                      kernel_size=3,
                      stride=3),
            nn.LeakyReLU()
        )
        # Third layer
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=kwargs.get('input_channels', None)*25,
                      out_channels=1536,
                      kernel_size=3,
                      stride=3),
            nn.LeakyReLU()
        )
        

        # Classification layer
        self.fc = nn.Sequential(
            Flatten(),
            nn.Linear(1536, kwargs.get('output_channels', None))
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.fc(x)
        return x

# %%
import numpy as np
import torch

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

def train(model, train_loader, optimizer, loss_fn, print_every=100):
    '''
    Trains the model for one epoch
    '''
    model.train()
    losses = []
    n_correct = 0
    for iteration, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        output = model(images)
        optimizer.zero_grad()
        loss = loss_fn(output, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
        n_correct += torch.sum(output.argmax(1) == labels).item()
    accuracy = 100.0 * n_correct / len(train_loader.dataset)
    return np.mean(np.array(losses)), accuracy
            
def test(model, test_loader, loss_fn):
    '''
    Tests the model on data from test_loader
    '''
    model.eval()
    test_loss = 0
    n_correct = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            output = model(images)
            loss = loss_fn(output, labels)
            test_loss += loss.item()
            n_correct += torch.sum(output.argmax(1) == labels).item()

    average_loss = test_loss / len(test_loader)
    accuracy = 100.0 * n_correct / len(test_loader.dataset)
    return average_loss, accuracy

def fit(train_dataloader, val_dataloader, model, optimizer, loss_fn, n_epochs, scheduler=None):
    train_losses, train_accuracies = [], []
    val_losses, val_accuracies = [], []

    for epoch in range(n_epochs):
        train_loss, train_accuracy = train(model, train_dataloader, optimizer, loss_fn)
        val_loss, val_accuracy = test(model, val_dataloader, loss_fn)
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)
        if scheduler:
            scheduler.step() # argument only needed for ReduceLROnPlateau
    
    return val_accuracies

# %%
transform_dataset = transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])

# %%
train_dataset = datasets.ImageFolder('mnist/train',transform=transform_dataset)

# %%
val_dataset = datasets.ImageFolder('mnist/val',transform=transform_dataset)

# %%
test_dataset = datasets.ImageFolder('mnist/test',transform=transform_dataset)

# %%
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=100, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset,batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset,batch_size=100, shuffle=True)

# %%
nb_epochs = 25
i = 0
for learning_rate in [0.001,0.002,0.01]:
    pre_defined_kwargs = {'input_dim': (28,28), 'input_channels': 3, 'output_channels': 10}
    model_cnn = PR_CNN(**pre_defined_kwargs)
    model_cnn = model_cnn.to(device)
    optimizer = torch.optim.Adam(model_cnn.parameters(), lr=learning_rate)
    loss_fn = nn.CrossEntropyLoss()
    accuracies = fit(train_loader, val_loader, model_cnn, optimizer, loss_fn, nb_epochs)
    plt.title('Learning rate:' + str(learning_rate))
    plt.plot(accuracies)
    plt.savefig('cnn_plot/'+str(i) + '.png')
    plt.show() 
    i = i + 1
# Out:
# Epoch 1/25: train_loss: 0.3149, train_accuracy: 90.3632, val_loss: 0.1512, val_accuracy: 95.4697
# Epoch 2/25: train_loss: 0.1055, train_accuracy: 96.7687, val_loss: 0.1055, val_accuracy: 96.6364
# Epoch 3/25: train_loss: 0.0691, train_accuracy: 97.8682, val_loss: 0.0857, val_accuracy: 97.1768
# Epoch 4/25: train_loss: 0.0491, train_accuracy: 98.4726, val_loss: 0.0982, val_accuracy: 97.0404
# Epoch 5/25: train_loss: 0.0362, train_accuracy: 98.8333, val_loss: 0.0728, val_accuracy: 97.7828
# Epoch 6/25: train_loss: 0.0265, train_accuracy: 99.1219, val_loss: 0.0887, val_accuracy: 97.5152
# Epoch 7/25: train_loss: 0.0232, train_accuracy: 99.2736, val_loss: 0.0779, val_accuracy: 97.9192
# Epoch 8/25: train_loss: 0.0203, train_accuracy: 99.3109, val_loss: 0.0878, val_accuracy: 97.6313
# Epoch 9/25: train_loss: 0.0143, train_accuracy: 99.5572, val_loss: 0.0880, val_accuracy: 97.7727
# Epoch 10/25: train_loss: 0.0136, train_accuracy: 99.5771, val_loss: 0.0826, val_accuracy: 97.8232
# Epoch 11/25: train_loss: 0.0110, train_accuracy: 99.6070, val_loss: 0.0908, val_accuracy: 97.9848
# Epoch 12/25: train_loss: 0.0155, train_accuracy: 99.4701, val_loss: 0.0916, val_accuracy: 97.7323
# Epoch 13/25: train_loss: 0.0077, train_accuracy: 99.7438, val_loss: 0.1057, val_accuracy: 97.6919
# Epoch 14/25: train_loss: 0.0101, train_accuracy: 99.6891, val_loss: 0.1111, val_accuracy: 97.7576
# Epoch 15/25: train_loss: 0.0142, train_accuracy: 99.5149, val_loss: 0.1086, val_accuracy: 97.8737
# Epoch 16/25: train_loss: 0.0083, train_accuracy: 99.7189, val_loss: 0.1026, val_accuracy: 97.9747
# Epoch 17/25: train_loss: 0.0070, train_accuracy: 99.7761, val_loss: 0.1196, val_accuracy: 97.9141
# Epoch 18/25: train_loss: 0.0082, train_accuracy: 99.7612, val_loss: 0.1289, val_accuracy: 97.6566
# Epoch 19/25: train_loss: 0.0120, train_accuracy: 99.5821, val_loss: 0.1097, val_accuracy: 97.8535
# Epoch 20/25: train_loss: 0.0053, train_accuracy: 99.8234, val_loss: 0.1230, val_accuracy: 97.8889
# Epoch 21/25: train_loss: 0.0068, train_accuracy: 99.7761, val_loss: 0.1257, val_accuracy: 97.5101
# Epoch 22/25: train_loss: 0.0098, train_accuracy: 99.7065, val_loss: 0.1153, val_accuracy: 98.0253
# Epoch 23/25: train_loss: 0.0059, train_accuracy: 99.8159, val_loss: 0.1080, val_accuracy: 98.0354
# Epoch 24/25: train_loss: 0.0055, train_accuracy: 99.8308, val_loss: 0.1207, val_accuracy: 98.0606
# Epoch 25/25: train_loss: 0.0056, train_accuracy: 99.8134, val_loss: 0.1200, val_accuracy: 97.9697
# Epoch 1/25: train_loss: 0.2612, train_accuracy: 91.9403, val_loss: 0.1353, val_accuracy: 95.5303
# Epoch 2/25: train_loss: 0.0815, train_accuracy: 97.4453, val_loss: 0.0912, val_accuracy: 97.2980
# Epoch 3/25: train_loss: 0.0541, train_accuracy: 98.2214, val_loss: 0.0868, val_accuracy: 97.3030
# Epoch 4/25: train_loss: 0.0390, train_accuracy: 98.7289, val_loss: 0.0763, val_accuracy: 97.7576
# Epoch 5/25: train_loss: 0.0278, train_accuracy: 99.0871, val_loss: 0.0978, val_accuracy: 97.5505
# Epoch 6/25: train_loss: 0.0268, train_accuracy: 99.0746, val_loss: 0.1092, val_accuracy: 97.3737
# Epoch 7/25: train_loss: 0.0229, train_accuracy: 99.2363, val_loss: 0.1086, val_accuracy: 97.5859
# Epoch 8/25: train_loss: 0.0237, train_accuracy: 99.2388, val_loss: 0.1024, val_accuracy: 97.6717
# Epoch 9/25: train_loss: 0.0185, train_accuracy: 99.3632, val_loss: 0.1220, val_accuracy: 97.6364
# Epoch 10/25: train_loss: 0.0186, train_accuracy: 99.3856, val_loss: 0.1220, val_accuracy: 97.5000
# Epoch 11/25: train_loss: 0.0123, train_accuracy: 99.6119, val_loss: 0.1217, val_accuracy: 97.8788
# Epoch 12/25: train_loss: 0.0228, train_accuracy: 99.2935, val_loss: 0.1165, val_accuracy: 97.6465
# Epoch 13/25: train_loss: 0.0098, train_accuracy: 99.6915, val_loss: 0.1342, val_accuracy: 97.6970
# Epoch 14/25: train_loss: 0.0163, train_accuracy: 99.5348, val_loss: 0.1223, val_accuracy: 97.9798
# Epoch 15/25: train_loss: 0.0139, train_accuracy: 99.5622, val_loss: 0.1513, val_accuracy: 97.5707
# Epoch 16/25: train_loss: 0.0172, train_accuracy: 99.5522, val_loss: 0.1481, val_accuracy: 97.6970
# Epoch 17/25: train_loss: 0.0112, train_accuracy: 99.6667, val_loss: 0.1374, val_accuracy: 97.9495
# Epoch 18/25: train_loss: 0.0141, train_accuracy: 99.6244, val_loss: 0.1511, val_accuracy: 97.7273
# Epoch 19/25: train_loss: 0.0184, train_accuracy: 99.5348, val_loss: 0.1490, val_accuracy: 97.7778
# Epoch 20/25: train_loss: 0.0094, train_accuracy: 99.7363, val_loss: 0.1616, val_accuracy: 97.9697
# Epoch 21/25: train_loss: 0.0123, train_accuracy: 99.6517, val_loss: 0.1725, val_accuracy: 97.8485
# Epoch 22/25: train_loss: 0.0107, train_accuracy: 99.7562, val_loss: 0.1937, val_accuracy: 97.6970
# Epoch 23/25: train_loss: 0.0140, train_accuracy: 99.6368, val_loss: 0.1687, val_accuracy: 98.0758
# Epoch 24/25: train_loss: 0.0146, train_accuracy: 99.6567, val_loss: 0.2163, val_accuracy: 97.7172
# Epoch 25/25: train_loss: 0.0155, train_accuracy: 99.6318, val_loss: 0.2092, val_accuracy: 98.0657
# Epoch 1/25: train_loss: 0.3589, train_accuracy: 89.4726, val_loss: 0.1512, val_accuracy: 95.2828
# Epoch 2/25: train_loss: 0.1450, train_accuracy: 95.7786, val_loss: 0.1422, val_accuracy: 95.9343
# Epoch 3/25: train_loss: 0.1254, train_accuracy: 96.4204, val_loss: 0.1379, val_accuracy: 96.6061
# Epoch 4/25: train_loss: 0.1145, train_accuracy: 96.9129, val_loss: 0.2031, val_accuracy: 95.4394
# Epoch 5/25: train_loss: 0.1263, train_accuracy: 96.9179, val_loss: 0.2835, val_accuracy: 94.4697
# Epoch 6/25: train_loss: 0.1572, train_accuracy: 96.3209, val_loss: 0.1978, val_accuracy: 95.9343
# Epoch 7/25: train_loss: 0.1345, train_accuracy: 96.9925, val_loss: 0.2564, val_accuracy: 95.9141
# Epoch 8/25: train_loss: 0.2983, train_accuracy: 95.6343, val_loss: 0.3778, val_accuracy: 94.1970
# Epoch 9/25: train_loss: 0.1793, train_accuracy: 96.7562, val_loss: 0.2576, val_accuracy: 95.8182
# Epoch 10/25: train_loss: 0.1176, train_accuracy: 97.6716, val_loss: 0.3942, val_accuracy: 95.2323
# Epoch 11/25: train_loss: 0.2255, train_accuracy: 96.7736, val_loss: 0.4010, val_accuracy: 95.6566
# Epoch 12/25: train_loss: 0.1687, train_accuracy: 97.3532, val_loss: 0.3294, val_accuracy: 95.6566
# Epoch 13/25: train_loss: 0.1889, train_accuracy: 97.1542, val_loss: 0.5381, val_accuracy: 94.9798
# Epoch 14/25: train_loss: 0.2216, train_accuracy: 96.9502, val_loss: 0.3150, val_accuracy: 96.4343
# Epoch 15/25: train_loss: 0.2059, train_accuracy: 97.2960, val_loss: 0.4887, val_accuracy: 95.0707
# Epoch 16/25: train_loss: 0.2273, train_accuracy: 97.2413, val_loss: 0.6471, val_accuracy: 94.8232
# Epoch 17/25: train_loss: 0.3578, train_accuracy: 96.3383, val_loss: 0.4194, val_accuracy: 95.8889
# Epoch 18/25: train_loss: 0.1321, train_accuracy: 98.0846, val_loss: 0.4256, val_accuracy: 96.7323
# Epoch 19/25: train_loss: 0.1744, train_accuracy: 97.9950, val_loss: 0.9577, val_accuracy: 93.0808
# Epoch 20/25: train_loss: 0.3673, train_accuracy: 97.1567, val_loss: 0.5895, val_accuracy: 95.9848
# Epoch 21/25: train_loss: 0.2470, train_accuracy: 97.7363, val_loss: 0.8458, val_accuracy: 95.9091
# Epoch 22/25: train_loss: 0.3108, train_accuracy: 97.5547, val_loss: 0.5824, val_accuracy: 96.1010
# Epoch 23/25: train_loss: 0.2183, train_accuracy: 98.0373, val_loss: 1.1028, val_accuracy: 94.8030
# Epoch 24/25: train_loss: 0.3552, train_accuracy: 97.4801, val_loss: 0.8965, val_accuracy: 96.1111
# Epoch 25/25: train_loss: 0.2113, train_accuracy: 98.2164, val_loss: 0.9394, val_accuracy: 95.3636
